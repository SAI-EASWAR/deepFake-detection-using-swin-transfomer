# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/swin\ transformer/modified\ data.zip -d data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/modified data/Validation/Fake/fake_8332.jpg
#   inflating: data/modified data/Validation/Fake/fake_8346.jpg
#   inflating: data/modified data/Validation/Fake/fake_8356.jpg
#   inflating: data/modified data/Validation/Fake/fake_8357.jpg
#   inflating: data/modified data/Validation/Fake/fake_8359.jpg
#   inflating: data/modified data/Validation/Fake/fake_8360.jpg
#   inflating: data/modified data/Validation/Fake/fake_8361.jpg
#   inflating: data/modified data/Validation/Fake/fake_8363.jpg
#   inflating: data/modified data/Validation/Fake/fake_8368.jpg
#   inflating: data/modified data/Validation/Fake/fake_8370.jpg
#   inflating: data/modified data/Validation/Fake/fake_8376.jpg
#   inflating: data/modified data/Validation/Fake/fake_8379.jpg
#   inflating: data/modified data/Validation/Fake/fake_8381.jpg
#   inflating: data/modified data/Validation/Fake/fake_8384.jpg
#   inflating: data/modified data/Validation/Fake/fake_8385.jpg
#   inflating: data/modified data/Validation/Fake/fake_8386.jpg
#   inflating: data/modified data/Validation/Fake/fake_8388.jpg
#   inflating: data/modified data/Validation/Fake/fake_8393.jpg
#   inflating: data/modified data/Validation/Fake/fake_8398.jpg
#   inflating: data/modified data/Validation/Fake/fake_8402.jpg
#   inflating: data/modified data/Validation/Fake/fake_8404.jpg
#   inflating: data/modified data/Validation/Fake/fake_8407.jpg
#   inflating: data/modified data/Validation/Fake/fake_8410.jpg
#   inflating: data/modified data/Validation/Fake/fake_8414.jpg
#   inflating: data/modified data/Validation/Fake/fake_8419.jpg
#   inflating: data/modified data/Validation/Fake/fake_842.jpg
#   inflating: data/modified data/Validation/Fake/fake_8421.jpg
#   inflating: data/modified data/Validation/Fake/fake_8423.jpg
#   inflating: data/modified data/Validation/Fake/fake_8426.jpg
#   inflating: data/modified data/Validation/Fake/fake_8427.jpg
#   inflating: data/modified data/Validation/Fake/fake_8439.jpg
#   inflating: data/modified data/Validation/Fake/fake_8441.jpg
#   inflating: data/modified data/Validation/Fake/fake_8445.jpg
#   inflating: data/modified data/Validation/Fake/fake_8446.jpg
#   inflating: data/modified data/Validation/Fake/fake_845.jpg
#   inflating: data/modified data/Validation/Fake/fake_8452.jpg
#   inflating: data/modified data/Validation/Fake/fake_8461.jpg
#   inflating: data/modified data/Validation/Fake/fake_8463.jpg
#   inflating: data/modified data/Validation/Fake/fake_8464.jpg
#   inflating: data/modified data/Validation/Fake/fake_8468.jpg
#   inflating: data/modified data/Validation/Fake/fake_8471.jpg
#   inflating: data/modified data/Validation/Fake/fake_8473.jpg
#   inflating: data/modified data/Validation/Fake/fake_8489.jpg
#   inflating: data/modified data/Validation/Fake/fake_849.jpg
#   inflating: data/modified data/Validation/Fake/fake_8497.jpg
#   inflating: data/modified data/Validation/Fake/fake_85.jpg
#   inflating: data/modified data/Validation/Fake/fake_8500.jpg
#   inflating: data/modified data/Validation/Fake/fake_8507.jpg
#   inflating: data/modified data/Validation/Fake/fake_8509.jpg
#   inflating: data/modified data/Validation/Fake/fake_8512.jpg
#   inflating: data/modified data/Validation/Fake/fake_8514.jpg
#   inflating: data/modified data/Validation/Fake/fake_8516.jpg
#   inflating: data/modified data/Validation/Fake/fake_8518.jpg
#   inflating: data/modified data/Validation/Fake/fake_852.jpg
#   inflating: data/modified data/Validation/Fake/fake_8522.jpg
#   inflating: data/modified data/Validation/Fake/fake_8523.jpg
#   inflating: data/modified data/Validation/Fake/fake_8524.jpg
#   inflating: data/modified data/Validation/Fake/fake_8532.jpg
#   inflating: data/modified data/Validation/Fake/fake_8541.jpg
#   inflating: data/modified data/Validation/Fake/fake_8542.jpg
#   inflating: data/modified data/Validation/Fake/fake_8550.jpg
#   inflating: data/modified data/Validation/Fake/fake_8551.jpg
#   inflating: data/modified data/Validation/Fake/fake_8556.jpg
#   inflating: data/modified data/Validation/Fake/fake_8562.jpg
#   inflating: data/modified data/Validation/Fake/fake_8566.jpg
#   inflating: data/modified data/Validation/Fake/fake_8572.jpg
#   inflating: data/modified data/Validation/Fake/fake_8574.jpg
#   inflating: data/modified data/Validation/Fake/fake_8577.jpg
#   inflating: data/modified data/Validation/Fake/fake_8578.jpg
#   inflating: data/modified data/Validation/Fake/fake_8582.jpg
#   inflating: data/modified data/Validation/Fake/fake_859.jpg
#   inflating: data/modified data/Validation/Fake/fake_8594.jpg
#   inflating: data/modified data/Validation/Fake/fake_8597.jpg
#   inflating: data/modified data/Validation/Fake/fake_8598.jpg
#   inflating: data/modified data/Validation/Fake/fake_86.jpg
#   inflating: data/modified data/Validation/Fake/fake_860.jpg
#   inflating: data/modified data/Validation/Fake/fake_8608.jpg
#   inflating: data/modified data/Validation/Fake/fake_862.jpg
#   inflating: data/modified data/Validation/Fake/fake_8622.jpg
#   inflating: data/modified data/Validation/Fake/fake_8624.jpg
#   inflating: data/modified data/Validation/Fake/fake_8627.jpg
#   inflating: data/modified data/Validation/Fake/fake_8629.jpg
#   inflating: data/modified data/Validation/Fake/fake_8636.jpg
#   inflating: data/modified data/Validation/Fake/fake_8638.jpg
#   inflating: data/modified data/Validation/Fake/fake_8640.jpg
#   inflating: data/modified data/Validation/Fake/fake_8649.jpg
#   inflating: data/modified data/Validation/Fake/fake_8651.jpg
#   inflating: data/modified data/Validation/Fake/fake_8652.jpg
#   inflating: data/modified data/Validation/Fake/fake_8656.jpg
#   inflating: data/modified data/Validation/Fake/fake_8657.jpg
#   inflating: data/modified data/Validation/Fake/fake_866.jpg
#   inflating: data/modified data/Validation/Fake/fake_867.jpg
#   inflating: data/modified data/Validation/Fake/fake_8678.jpg
#   inflating: data/modified data/Validation/Fake/fake_8679.jpg
#   inflating: data/modified data/Validation/Fake/fake_8683.jpg
#   inflating: data/modified data/Validation/Fake/fake_8690.jpg
#   inflating: data/modified data/Validation/Fake/fake_8693.jpg
#   inflating: data/modified data/Validation/Fake/fake_8694.jpg
#   inflating: data/modified data/Validation/Fake/fake_8698.jpg
#   inflating: data/modified data/Validation/Fake/fake_8701.jpg
#   inflating: data/modified data/Validation/Fake/fake_8703.jpg
#   inflating: data/modified data/Validation/Fake/fake_8705.jpg
#   inflating: data/modified data/Validation/Fake/fake_8711.jpg
#   inflating: data/modified data/Validation/Fake/fake_8715.jpg
#   inflating: data/modified data/Validation/Fake/fake_8717.jpg
#   inflating: data/modified data/Validation/Fake/fake_8718.jpg
#   inflating: data/modified data/Validation/Fake/fake_8722.jpg
#   inflating: data/modified data/Validation/Fake/fake_8724.jpg
#   inflating: data/modified data/Validation/Fake/fake_8731.jpg
#   inflating: data/modified data/Validation/Fake/fake_8732.jpg
#   inflating: data/modified data/Validation/Fake/fake_8737.jpg
#   inflating: data/modified data/Validation/Fake/fake_8742.jpg
#   inflating: data/modified data/Validation/Fake/fake_8765.jpg
#   inflating: data/modified data/Validation/Fake/fake_8770.jpg
#   inflating: data/modified data/Validation/Fake/fake_8771.jpg
#   inflating: data/modified data/Validation/Fake/fake_8780.jpg
#   inflating: data/modified data/Validation/Fake/fake_8784.jpg
#   inflating: data/modified data/Validation/Fake/fake_8789.jpg
#   inflating: data/modified data/Validation/Fake/fake_8790.jpg
#   inflating: data/modified data/Validation/Fake/fake_8792.jpg
#   inflating: data/modified data/Validation/Fake/fake_8799.jpg
#   inflating: data/modified data/Validation/Fake/fake_880.jpg
#   inflating: data/modified data/Validation/Fake/fake_8802.jpg
#   inflating: data/modified data/Validation/Fake/fake_8813.jpg
#   inflating: data/modified data/Validation/Fake/fake_8814.jpg
#   inflating: data/modified data/Validation/Fake/fake_8815.jpg
#   inflating: data/modified data/Validation/Fake/fake_8821.jpg
#   inflating: data/modified data/Validation/Fake/fake_8825.jpg
#   inflating: data/modified data/Validation/Fake/fake_8826.jpg
#   inflating: data/modified data/Validation/Fake/fake_8832.jpg
#   inflating: data/modified data/Validation/Fake/fake_8835.jpg
#   inflating: data/modified data/Validation/Fake/fake_8838.jpg
#   inflating: data/modified data/Validation/Fake/fake_884.jpg
#   inflating: data/modified data/Validation/Fake/fake_8844.jpg
#   inflating: data/modified data/Validation/Fake/fake_8845.jpg
#   inflating: data/modified data/Validation/Fake/fake_8852.jpg
#   inflating: data/modified data/Validation/Fake/fake_8857.jpg
#   inflating: data/modified data/Validation/Fake/fake_8860.jpg
#   inflating: data/modified data/Validation/Fake/fake_8861.jpg
#   inflating: data/modified data/Validation/Fake/fake_8872.jpg
#   inflating: data/modified data/Validation/Fake/fake_8877.jpg
#   inflating: data/modified data/Validation/Fake/fake_8882.jpg
#   inflating: data/modified data/Validation/Fake/fake_8893.jpg
#   inflating: data/modified data/Validation/Fake/fake_8897.jpg
#   inflating: data/modified data/Validation/Fake/fake_89.jpg
#   inflating: data/modified data/Validation/Fake/fake_8901.jpg
#   inflating: data/modified data/Validation/Fake/fake_8902.jpg
#   inflating: data/modified data/Validation/Fake/fake_8903.jpg
#   inflating: data/modified data/Validation/Fake/fake_8905.jpg
#   inflating: data/modified data/Validation/Fake/fake_8910.jpg
#   inflating: data/modified data/Validation/Fake/fake_8911.jpg
#   inflating: data/modified data/Validation/Fake/fake_8912.jpg
#   inflating: data/modified data/Validation/Fake/fake_8917.jpg
#   inflating: data/modified data/Validation/Fake/fake_8925.jpg
#   inflating: data/modified data/Validation/Fake/fake_8930.jpg
#   inflating: data/modified data/Validation/Fake/fake_8934.jpg
#   inflating: data/modified data/Validation/Fake/fake_8939.jpg
#   inflating: data/modified data/Validation/Fake/fake_8947.jpg
#   inflating: data/modified data/Validation/Fake/fake_8951.jpg
#   inflating: data/modified data/Validation/Fake/fake_8953.jpg
#   inflating: data/modified data/Validation/Fake/fake_8954.jpg
#   inflating: data/modified data/Validation/Fake/fake_8955.jpg
#   inflating: data/modified data/Validation/Fake/fake_8956.jpg
#   inflating: data/modified data/Validation/Fake/fake_8957.jpg
#   inflating: data/modified data/Validation/Fake/fake_8958.jpg
#   inflating: data/modified data/Validation/Fake/fake_8963.jpg
#   inflating: data/modified data/Validation/Fake/fake_8976.jpg
#   inflating: data/modified data/Validation/Fake/fake_898.jpg
#   inflating: data/modified data/Validation/Fake/fake_8983.jpg
#   inflating: data/modified data/Validation/Fake/fake_8984.jpg
#   inflating: data/modified data/Validation/Fake/fake_8993.jpg
#   inflating: data/modified data/Validation/Fake/fake_8998.jpg
#   inflating: data/modified data/Validation/Fake/fake_90.jpg
#   inflating: data/modified data/Validation/Fake/fake_9004.jpg
#   inflating: data/modified data/Validation/Fake/fake_9008.jpg
#   inflating: data/modified data/Validation/Fake/fake_9011.jpg
#   inflating: data/modified data/Validation/Fake/fake_9012.jpg
#   inflating: data/modified data/Validation/Fake/fake_9015.jpg
#   inflating: data/modified data/Validation/Fake/fake_9019.jpg
#   inflating: data/modified data/Validation/Fake/fake_9024.jpg
#   inflating: data/modified data/Validation/Fake/fake_9028.jpg
#   inflating: data/modified data/Validation/Fake/fake_9032.jpg
#   inflating: data/modified data/Validation/Fake/fake_9033.jpg
#   inflating: data/modified data/Validation/Fake/fake_9038.jpg
#   inflating: data/modified data/Validation/Fake/fake_904.jpg
#   inflating: data/modified data/Validation/Fake/fake_9043.jpg
#   inflating: data/modified data/Validation/Fake/fake_9045.jpg
#   inflating: data/modified data/Validation/Fake/fake_9049.jpg
#   inflating: data/modified data/Validation/Fake/fake_905.jpg
#   inflating: data/modified data/Validation/Fake/fake_9056.jpg
#   inflating: data/modified data/Validation/Fake/fake_9063.jpg
#   inflating: data/modified data/Validation/Fake/fake_9066.jpg
#   inflating: data/modified data/Validation/Fake/fake_9068.jpg
#   inflating: data/modified data/Validation/Fake/fake_9069.jpg
#   inflating: data/modified data/Validation/Fake/fake_907.jpg
#   inflating: data/modified data/Validation/Fake/fake_9071.jpg
#   inflating: data/modified data/Validation/Fake/fake_9079.jpg
#   inflating: data/modified data/Validation/Fake/fake_9081.jpg
#   inflating: data/modified data/Validation/Fake/fake_9086.jpg
#   inflating: data/modified data/Validation/Fake/fake_9091.jpg
#   inflating: data/modified data/Validation/Fake/fake_9093.jpg
#   inflating: data/modified data/Validation/Fake/fake_9095.jpg
#   inflating: data/modified data/Validation/Fake/fake_9097.jpg
#   inflating: data/modified data/Validation/Fake/fake_910.jpg
#   inflating: data/modified data/Validation/Fake/fake_9101.jpg
#   inflating: data/modified data/Validation/Fake/fake_9114.jpg
#   inflating: data/modified data/Validation/Fake/fake_9118.jpg
#   inflating: data/modified data/Validation/Fake/fake_9119.jpg
#   inflating: data/modified data/Validation/Fake/fake_912.jpg
#   inflating: data/modified data/Validation/Fake/fake_9129.jpg
#   inflating: data/modified data/Validation/Fake/fake_9134.jpg
#   inflating: data/modified data/Validation/Fake/fake_9135.jpg
#   inflating: data/modified data/Validation/Fake/fake_9136.jpg
#   inflating: data/modified data/Validation/Fake/fake_9141.jpg
#   inflating: data/modified data/Validation/Fake/fake_9145.jpg
#   inflating: data/modified data/Validation/Fake/fake_9147.jpg
#   inflating: data/modified data/Validation/Fake/fake_9152.jpg
#   inflating: data/modified data/Validation/Fake/fake_9154.jpg
#   inflating: data/modified data/Validation/Fake/fake_9167.jpg
#   inflating: data/modified data/Validation/Fake/fake_9168.jpg
#   inflating: data/modified data/Validation/Fake/fake_9169.jpg
#   inflating: data/modified data/Validation/Fake/fake_9171.jpg
#   inflating: data/modified data/Validation/Fake/fake_9175.jpg
#   inflating: data/modified data/Validation/Fake/fake_9176.jpg
#   inflating: data/modified data/Validation/Fake/fake_9179.jpg
#   inflating: data/modified data/Validation/Fake/fake_9183.jpg
#   inflating: data/modified data/Validation/Fake/fake_9187.jpg
#   inflating: data/modified data/Validation/Fake/fake_9189.jpg
#   inflating: data/modified data/Validation/Fake/fake_9193.jpg
#   inflating: data/modified data/Validation/Fake/fake_9196.jpg
#   inflating: data/modified data/Validation/Fake/fake_9198.jpg
#   inflating: data/modified data/Validation/Fake/fake_920.jpg
#   inflating: data/modified data/Validation/Fake/fake_9217.jpg
#   inflating: data/modified data/Validation/Fake/fake_922.jpg
#   inflating: data/modified data/Validation/Fake/fake_9224.jpg
#   inflating: data/modified data/Validation/Fake/fake_9226.jpg
#   inflating: data/modified data/Validation/Fake/fake_9227.jpg
#   inflating: data/modified data/Validation/Fake/fake_9231.jpg
#   inflating: data/modified data/Validation/Fake/fake_9234.jpg
#   inflating: data/modified data/Validation/Fake/fake_9235.jpg
#   inflating: data/modified data/Validation/Fake/fake_9236.jpg
#   inflating: data/modified data/Validation/Fake/fake_9240.jpg
#   inflating: data/modified data/Validation/Fake/fake_9243.jpg
#   inflating: data/modified data/Validation/Fake/fake_9244.jpg
#   inflating: data/modified data/Validation/Fake/fake_9245.jpg
#   inflating: data/modified data/Validation/Fake/fake_9246.jpg
#   inflating: data/modified data/Validation/Fake/fake_9251.jpg
#   inflating: data/modified data/Validation/Fake/fake_9255.jpg
#   inflating: data/modified data/Validation/Fake/fake_9269.jpg
#   inflating: data/modified data/Validation/Fake/fake_9273.jpg
#   inflating: data/modified data/Validation/Fake/fake_9277.jpg
#   inflating: data/modified data/Validation/Fake/fake_9282.jpg
#   inflating: data/modified data/Validation/Fake/fake_9283.jpg
#   inflating: data/modified data/Validation/Fake/fake_9284.jpg
#   inflating: data/modified data/Validation/Fake/fake_9288.jpg
#   inflating: data/modified data/Validation/Fake/fake_9290.jpg
#   inflating: data/modified data/Validation/Fake/fake_9294.jpg
#   inflating: data/modified data/Validation/Fake/fake_9295.jpg
#   inflating: data/modified data/Validation/Fake/fake_93.jpg
#   inflating: data/modified data/Validation/Fake/fake_9301.jpg
#   inflating: data/modified data/Validation/Fake/fake_9302.jpg
#   inflating: data/modified data/Validation/Fake/fake_9307.jpg
#   inflating: data/modified data/Validation/Fake/fake_931.jpg
#   inflating: data/modified data/Validation/Fake/fake_9312.jpg
#   inflating: data/modified data/Validation/Fake/fake_9313.jpg
#   inflating: data/modified data/Validation/Fake/fake_9318.jpg
#   inflating: data/modified data/Validation/Fake/fake_932.jpg
#   inflating: data/modified data/Validation/Fake/fake_9323.jpg
#   inflating: data/modified data/Validation/Fake/fake_9327.jpg
#   inflating: data/modified data/Validation/Fake/fake_9328.jpg
#   inflating: data/modified data/Validation/Fake/fake_9331.jpg
#   inflating: data/modified data/Validation/Fake/fake_9333.jpg
#   inflating: data/modified data/Validation/Fake/fake_9342.jpg
#   inflating: data/modified data/Validation/Fake/fake_935.jpg
#   inflating: data/modified data/Validation/Fake/fake_9352.jpg
#   inflating: data/modified data/Validation/Fake/fake_9355.jpg
#   inflating: data/modified data/Validation/Fake/fake_9358.jpg
#   inflating: data/modified data/Validation/Fake/fake_9366.jpg
#   inflating: data/modified data/Validation/Fake/fake_9368.jpg
#   inflating: data/modified data/Validation/Fake/fake_937.jpg
#   inflating: data/modified data/Validation/Fake/fake_9371.jpg
#   inflating: data/modified data/Validation/Fake/fake_9372.jpg
#   inflating: data/modified data/Validation/Fake/fake_9375.jpg
#   inflating: data/modified data/Validation/Fake/fake_9376.jpg
#   inflating: data/modified data/Validation/Fake/fake_9380.jpg
#   inflating: data/modified data/Validation/Fake/fake_9395.jpg
#   inflating: data/modified data/Validation/Fake/fake_940.jpg
#   inflating: data/modified data/Validation/Fake/fake_9400.jpg
#   inflating: data/modified data/Validation/Fake/fake_9401.jpg
#   inflating: data/modified data/Validation/Fake/fake_9402.jpg
#   inflating: data/modified data/Validation/Fake/fake_9403.jpg
#   inflating: data/modified data/Validation/Fake/fake_9404.jpg
#   inflating: data/modified data/Validation/Fake/fake_9405.jpg
#   inflating: data/modified data/Validation/Fake/fake_9407.jpg
#   inflating: data/modified data/Validation/Fake/fake_941.jpg
#   inflating: data/modified data/Validation/Fake/fake_9415.jpg
#   inflating: data/modified data/Validation/Fake/fake_9416.jpg
#   inflating: data/modified data/Validation/Fake/fake_9419.jpg
#   inflating: data/modified data/Validation/Fake/fake_9427.jpg
#   inflating: data/modified data/Validation/Fake/fake_9428.jpg
#   inflating: data/modified data/Validation/Fake/fake_943.jpg
#   inflating: data/modified data/Validation/Fake/fake_9433.jpg
#   inflating: data/modified data/Validation/Fake/fake_9436.jpg
#   inflating: data/modified data/Validation/Fake/fake_9445.jpg
#   inflating: data/modified data/Validation/Fake/fake_9457.jpg
#   inflating: data/modified data/Validation/Fake/fake_9466.jpg
#   inflating: data/modified data/Validation/Fake/fake_9467.jpg
#   inflating: data/modified data/Validation/Fake/fake_9468.jpg
#   inflating: data/modified data/Validation/Fake/fake_9475.jpg
#   inflating: data/modified data/Validation/Fake/fake_9478.jpg
#   inflating: data/modified data/Validation/Fake/fake_9481.jpg
#   inflating: data/modified data/Validation/Fake/fake_9482.jpg
#   inflating: data/modified data/Validation/Fake/fake_9485.jpg
#   inflating: data/modified data/Validation/Fake/fake_9497.jpg
#   inflating: data/modified data/Validation/Fake/fake_9502.jpg
#   inflating: data/modified data/Validation/Fake/fake_9503.jpg
#   inflating: data/modified data/Validation/Fake/fake_9508.jpg
#   inflating: data/modified data/Validation/Fake/fake_9509.jpg
#   inflating: data/modified data/Validation/Fake/fake_951.jpg
#   inflating: data/modified data/Validation/Fake/fake_9515.jpg
#   inflating: data/modified data/Validation/Fake/fake_9516.jpg
#   inflating: data/modified data/Validation/Fake/fake_9518.jpg
#   inflating: data/modified data/Validation/Fake/fake_9532.jpg
#   inflating: data/modified data/Validation/Fake/fake_9534.jpg
#   inflating: data/modified data/Validation/Fake/fake_9542.jpg
#   inflating: data/modified data/Validation/Fake/fake_9543.jpg
#   inflating: data/modified data/Validation/Fake/fake_9544.jpg
#   inflating: data/modified data/Validation/Fake/fake_9547.jpg
#   inflating: data/modified data/Validation/Fake/fake_9548.jpg
#   inflating: data/modified data/Validation/Fake/fake_9549.jpg
#   inflating: data/modified data/Validation/Fake/fake_9550.jpg
#   inflating: data/modified data/Validation/Fake/fake_9551.jpg
#   inflating: data/modified data/Validation/Fake/fake_9552.jpg
#   inflating: data/modified data/Validation/Fake/fake_9553.jpg
#   inflating: data/modified data/Validation/Fake/fake_9559.jpg
#   inflating: data/modified data/Validation/Fake/fake_9561.jpg
#   inflating: data/modified data/Validation/Fake/fake_9563.jpg
#   inflating: data/modified data/Validation/Fake/fake_9564.jpg
#   inflating: data/modified data/Validation/Fake/fake_9566.jpg
#   inflating: data/modified data/Validation/Fake/fake_9569.jpg
#   inflating: data/modified data/Validation/Fake/fake_9570.jpg
#   inflating: data/modified data/Validation/Fake/fake_9577.jpg
#   inflating: data/modified data/Validation/Fake/fake_958.jpg
#   inflating: data/modified data/Validation/Fake/fake_9582.jpg
#   inflating: data/modified data/Validation/Fake/fake_9585.jpg
#   inflating: data/modified data/Validation/Fake/fake_9588.jpg
#   inflating: data/modified data/Validation/Fake/fake_9590.jpg
#   inflating: data/modified data/Validation/Fake/fake_9603.jpg
#   inflating: data/modified data/Validation/Fake/fake_9608.jpg
#   inflating: data/modified data/Validation/Fake/fake_9609.jpg
#   inflating: data/modified data/Validation/Fake/fake_9611.jpg
#   inflating: data/modified data/Validation/Fake/fake_9612.jpg
#   inflating: data/modified data/Validation/Fake/fake_9613.jpg
#   inflating: data/modified data/Validation/Fake/fake_9614.jpg
#   inflating: data/modified data/Validation/Fake/fake_9615.jpg
#   inflating: data/modified data/Validation/Fake/fake_9619.jpg
#   inflating: data/modified data/Validation/Fake/fake_962.jpg
#   inflating: data/modified data/Validation/Fake/fake_9623.jpg
#   inflating: data/modified data/Validation/Fake/fake_9637.jpg
#   inflating: data/modified data/Validation/Fake/fake_9641.jpg
#   inflating: data/modified data/Validation/Fake/fake_9644.jpg
#   inflating: data/modified data/Validation/Fake/fake_9649.jpg
#   inflating: data/modified data/Validation/Fake/fake_9650.jpg
#   inflating: data/modified data/Validation/Fake/fake_9651.jpg
#   inflating: data/modified data/Validation/Fake/fake_9669.jpg
#   inflating: data/modified data/Validation/Fake/fake_9673.jpg
#   inflating: data/modified data/Validation/Fake/fake_9674.jpg
#   inflating: data/modified data/Validation/Fake/fake_9675.jpg
#   inflating: data/modified data/Validation/Fake/fake_9677.jpg
#   inflating: data/modified data/Validation/Fake/fake_9679.jpg
#   inflating: data/modified data/Validation/Fake/fake_968.jpg
#   inflating: data/modified data/Validation/Fake/fake_9680.jpg
#   inflating: data/modified data/Validation/Fake/fake_969.jpg
#   inflating: data/modified data/Validation/Fake/fake_9692.jpg
#   inflating: data/modified data/Validation/Fake/fake_9699.jpg
#   inflating: data/modified data/Validation/Fake/fake_97.jpg
#   inflating: data/modified data/Validation/Fake/fake_9700.jpg
#   inflating: data/modified data/Validation/Fake/fake_9709.jpg
#   inflating: data/modified data/Validation/Fake/fake_9722.jpg
#   inflating: data/modified data/Validation/Fake/fake_9723.jpg
#   inflating: data/modified data/Validation/Fake/fake_9727.jpg
#   inflating: data/modified data/Validation/Fake/fake_9728.jpg
#   inflating: data/modified data/Validation/Fake/fake_9744.jpg
#   inflating: data/modified data/Validation/Fake/fake_9747.jpg
#   inflating: data/modified data/Validation/Fake/fake_975.jpg
#   inflating: data/modified data/Validation/Fake/fake_976.jpg
#   inflating: data/modified data/Validation/Fake/fake_9760.jpg
#   inflating: data/modified data/Validation/Fake/fake_9765.jpg
#   inflating: data/modified data/Validation/Fake/fake_9769.jpg
#   inflating: data/modified data/Validation/Fake/fake_9773.jpg
#   inflating: data/modified data/Validation/Fake/fake_9775.jpg
#   inflating: data/modified data/Validation/Fake/fake_9777.jpg
#   inflating: data/modified data/Validation/Fake/fake_9778.jpg
#   inflating: data/modified data/Validation/Fake/fake_9779.jpg
#   inflating: data/modified data/Validation/Fake/fake_978.jpg
#   inflating: data/modified data/Validation/Fake/fake_9785.jpg
#   inflating: data/modified data/Validation/Fake/fake_9787.jpg
#   inflating: data/modified data/Validation/Fake/fake_9789.jpg
#   inflating: data/modified data/Validation/Fake/fake_9798.jpg
#   inflating: data/modified data/Validation/Fake/fake_9800.jpg
#   inflating: data/modified data/Validation/Fake/fake_9804.jpg
#   inflating: data/modified data/Validation/Fake/fake_9813.jpg
#   inflating: data/modified data/Validation/Fake/fake_9814.jpg
#   inflating: data/modified data/Validation/Fake/fake_9815.jpg
#   inflating: data/modified data/Validation/Fake/fake_982.jpg
#   inflating: data/modified data/Validation/Fake/fake_9826.jpg
#   inflating: data/modified data/Validation/Fake/fake_9830.jpg
#   inflating: data/modified data/Validation/Fake/fake_984.jpg
#   inflating: data/modified data/Validation/Fake/fake_9844.jpg
#   inflating: data/modified data/Validation/Fake/fake_9859.jpg
#   inflating: data/modified data/Validation/Fake/fake_9861.jpg
#   inflating: data/modified data/Validation/Fake/fake_987.jpg
#   inflating: data/modified data/Validation/Fake/fake_9871.jpg
#   inflating: data/modified data/Validation/Fake/fake_9874.jpg
#   inflating: data/modified data/Validation/Fake/fake_9875.jpg
#   inflating: data/modified data/Validation/Fake/fake_9886.jpg
#   inflating: data/modified data/Validation/Fake/fake_9895.jpg
#   inflating: data/modified data/Validation/Fake/fake_9899.jpg
#   inflating: data/modified data/Validation/Fake/fake_990.jpg
#   inflating: data/modified data/Validation/Fake/fake_9904.jpg
#   inflating: data/modified data/Validation/Fake/fake_9909.jpg
#   inflating: data/modified data/Validation/Fake/fake_9910.jpg
#   inflating: data/modified data/Validation/Fake/fake_9913.jpg
#   inflating: data/modified data/Validation/Fake/fake_9915.jpg
#   inflating: data/modified data/Validation/Fake/fake_9916.jpg
#   inflating: data/modified data/Validation/Fake/fake_9920.jpg
#   inflating: data/modified data/Validation/Fake/fake_9923.jpg
#   inflating: data/modified data/Validation/Fake/fake_9927.jpg
#   inflating: data/modified data/Validation/Fake/fake_9931.jpg
#   inflating: data/modified data/Validation/Fake/fake_9936.jpg
#   inflating: data/modified data/Validation/Fake/fake_9937.jpg
#   inflating: data/modified data/Validation/Fake/fake_9947.jpg
#   inflating: data/modified data/Validation/Fake/fake_9950.jpg
#   inflating: data/modified data/Validation/Fake/fake_9955.jpg
#   inflating: data/modified data/Validation/Fake/fake_9956.jpg
#   inflating: data/modified data/Validation/Fake/fake_9960.jpg
#   inflating: data/modified data/Validation/Fake/fake_9962.jpg
#   inflating: data/modified data/Validation/Fake/fake_9964.jpg
#   inflating: data/modified data/Validation/Fake/fake_9965.jpg
#   inflating: data/modified data/Validation/Fake/fake_9969.jpg
#   inflating: data/modified data/Validation/Fake/fake_9972.jpg
#   inflating: data/modified data/Validation/Fake/fake_9973.jpg
#   inflating: data/modified data/Validation/Fake/fake_9974.jpg
#   inflating: data/modified data/Validation/Fake/fake_9976.jpg
#   inflating: data/modified data/Validation/Fake/fake_9985.jpg
#   inflating: data/modified data/Validation/Fake/fake_9988.jpg
#   inflating: data/modified data/Validation/Fake/fake_9990.jpg
#   inflating: data/modified data/Validation/Fake/fake_9999.jpg
#    creating: data/modified data/Validation/Real/
#   inflating: data/modified data/Validation/Real/real_10006.jpg
#   inflating: data/modified data/Validation/Real/real_10007.jpg
#   inflating: data/modified data/Validation/Real/real_10014.jpg
#   inflating: data/modified data/Validation/Real/real_10015.jpg
#   inflating: data/modified data/Validation/Real/real_10018.jpg
#   inflating: data/modified data/Validation/Real/real_10019.jpg
#   inflating: data/modified data/Validation/Real/real_10027.jpg
#   inflating: data/modified data/Validation/Real/real_10028.jpg
#   inflating: data/modified data/Validation/Real/real_1003.jpg
#   inflating: data/modified data/Validation/Real/real_10031.jpg
#   inflating: data/modified data/Validation/Real/real_10032.jpg
#   inflating: data/modified data/Validation/Real/real_1004.jpg
#   inflating: data/modified data/Validation/Real/real_10045.jpg
#   inflating: data/modified data/Validation/Real/real_10046.jpg
#   inflating: data/modified data/Validation/Real/real_10051.jpg
#   inflating: data/modified data/Validation/Real/real_10052.jpg
#   inflating: data/modified data/Validation/Real/real_10055.jpg
#   inflating: data/modified data/Validation/Real/real_10057.jpg
#   inflating: data/modified data/Validation/Real/real_10060.jpg
#   inflating: data/modified data/Validation/Real/real_10061.jpg
#   inflating: data/modified data/Validation/Real/real_10068.jpg
#   inflating: data/modified data/Validation/Real/real_1007.jpg
#   inflating: data/modified data/Validation/Real/real_10074.jpg
#   inflating: data/modified data/Validation/Real/real_10081.jpg
#   inflating: data/modified data/Validation/Real/real_10083.jpg
#   inflating: data/modified data/Validation/Real/real_10084.jpg
#   inflating: data/modified data/Validation/Real/real_1009.jpg
#   inflating: data/modified data/Validation/Real/real_10104.jpg
#   inflating: data/modified data/Validation/Real/real_10108.jpg
#   inflating: data/modified data/Validation/Real/real_10110.jpg
#   inflating: data/modified data/Validation/Real/real_10111.jpg
#   inflating: data/modified data/Validation/Real/real_10113.jpg
#   inflating: data/modified data/Validation/Real/real_10116.jpg
#   inflating: data/modified data/Validation/Real/real_10123.jpg
#   inflating: data/modified data/Validation/Real/real_10125.jpg
#   inflating: data/modified data/Validation/Real/real_10138.jpg
#   inflating: data/modified data/Validation/Real/real_10139.jpg
#   inflating: data/modified data/Validation/Real/real_10146.jpg
#   inflating: data/modified data/Validation/Real/real_10147.jpg
#   inflating: data/modified data/Validation/Real/real_10151.jpg
#   inflating: data/modified data/Validation/Real/real_10157.jpg
#   inflating: data/modified data/Validation/Real/real_1017.jpg
#   inflating: data/modified data/Validation/Real/real_10171.jpg
#   inflating: data/modified data/Validation/Real/real_10186.jpg
#   inflating: data/modified data/Validation/Real/real_10192.jpg
#   inflating: data/modified data/Validation/Real/real_10199.jpg
#   inflating: data/modified data/Validation/Real/real_102.jpg
#   inflating: data/modified data/Validation/Real/real_10209.jpg
#   inflating: data/modified data/Validation/Real/real_10214.jpg
#   inflating: data/modified data/Validation/Real/real_10219.jpg
#   inflating: data/modified data/Validation/Real/real_10224.jpg
#   inflating: data/modified data/Validation/Real/real_10228.jpg
#   inflating: data/modified data/Validation/Real/real_10233.jpg
#   inflating: data/modified data/Validation/Real/real_10235.jpg
#   inflating: data/modified data/Validation/Real/real_10261.jpg
#   inflating: data/modified data/Validation/Real/real_10262.jpg
#   inflating: data/modified data/Validation/Real/real_10267.jpg
#   inflating: data/modified data/Validation/Real/real_10272.jpg
#   inflating: data/modified data/Validation/Real/real_10276.jpg
#   inflating: data/modified data/Validation/Real/real_10279.jpg
#   inflating: data/modified data/Validation/Real/real_10283.jpg
#   inflating: data/modified data/Validation/Real/real_10285.jpg
#   inflating: data/modified data/Validation/Real/real_10290.jpg
#   inflating: data/modified data/Validation/Real/real_10292.jpg
#   inflating: data/modified data/Validation/Real/real_10296.jpg
#   inflating: data/modified data/Validation/Real/real_10304.jpg
#   inflating: data/modified data/Validation/Real/real_10305.jpg
#   inflating: data/modified data/Validation/Real/real_10306.jpg
#   inflating: data/modified data/Validation/Real/real_10307.jpg
#   inflating: data/modified data/Validation/Real/real_1031.jpg
#   inflating: data/modified data/Validation/Real/real_10315.jpg
#   inflating: data/modified data/Validation/Real/real_10319.jpg
#   inflating: data/modified data/Validation/Real/real_1032.jpg
#   inflating: data/modified data/Validation/Real/real_10322.jpg
#   inflating: data/modified data/Validation/Real/real_10326.jpg
#   inflating: data/modified data/Validation/Real/real_10331.jpg
#   inflating: data/modified data/Validation/Real/real_10332.jpg
#   inflating: data/modified data/Validation/Real/real_10335.jpg
#   inflating: data/modified data/Validation/Real/real_10336.jpg
#   inflating: data/modified data/Validation/Real/real_10337.jpg
#   inflating: data/modified data/Validation/Real/real_10338.jpg
#   inflating: data/modified data/Validation/Real/real_10339.jpg
#   inflating: data/modified data/Validation/Real/real_10340.jpg
#   inflating: data/modified data/Validation/Real/real_10342.jpg
#   inflating: data/modified data/Validation/Real/real_10345.jpg
#   inflating: data/modified data/Validation/Real/real_10347.jpg
#   inflating: data/modified data/Validation/Real/real_1035.jpg
#   inflating: data/modified data/Validation/Real/real_10358.jpg
#   inflating: data/modified data/Validation/Real/real_10362.jpg
#   inflating: data/modified data/Validation/Real/real_10370.jpg
#   inflating: data/modified data/Validation/Real/real_10378.jpg
#   inflating: data/modified data/Validation/Real/real_1038.jpg
#   inflating: data/modified data/Validation/Real/real_10381.jpg
#   inflating: data/modified data/Validation/Real/real_10382.jpg
#   inflating: data/modified data/Validation/Real/real_10385.jpg
#   inflating: data/modified data/Validation/Real/real_10394.jpg
#   inflating: data/modified data/Validation/Real/real_10396.jpg
#   inflating: data/modified data/Validation/Real/real_10399.jpg
#   inflating: data/modified data/Validation/Real/real_10400.jpg
#   inflating: data/modified data/Validation/Real/real_10403.jpg
#   inflating: data/modified data/Validation/Real/real_10411.jpg
#   inflating: data/modified data/Validation/Real/real_10412.jpg
#   inflating: data/modified data/Validation/Real/real_10413.jpg
#   inflating: data/modified data/Validation/Real/real_10418.jpg
#   inflating: data/modified data/Validation/Real/real_1042.jpg
#   inflating: data/modified data/Validation/Real/real_10423.jpg
#   inflating: data/modified data/Validation/Real/real_10428.jpg
#   inflating: data/modified data/Validation/Real/real_10430.jpg
#   inflating: data/modified data/Validation/Real/real_10433.jpg
#   inflating: data/modified data/Validation/Real/real_10436.jpg
#   inflating: data/modified data/Validation/Real/real_10439.jpg
#   inflating: data/modified data/Validation/Real/real_10441.jpg
#   inflating: data/modified data/Validation/Real/real_10442.jpg
#   inflating: data/modified data/Validation/Real/real_10446.jpg
#   inflating: data/modified data/Validation/Real/real_10449.jpg
#   inflating: data/modified data/Validation/Real/real_10455.jpg
#   inflating: data/modified data/Validation/Real/real_10459.jpg
#   inflating: data/modified data/Validation/Real/real_10468.jpg
#   inflating: data/modified data/Validation/Real/real_1047.jpg
#   inflating: data/modified data/Validation/Real/real_10473.jpg
#   inflating: data/modified data/Validation/Real/real_10475.jpg
#   inflating: data/modified data/Validation/Real/real_10476.jpg
#   inflating: data/modified data/Validation/Real/real_10479.jpg
#   inflating: data/modified data/Validation/Real/real_10489.jpg
#   inflating: data/modified data/Validation/Real/real_10493.jpg
#   inflating: data/modified data/Validation/Real/real_10502.jpg
#   inflating: data/modified data/Validation/Real/real_10508.jpg
#   inflating: data/modified data/Validation/Real/real_10516.jpg
#   inflating: data/modified data/Validation/Real/real_10519.jpg
#   inflating: data/modified data/Validation/Real/real_10531.jpg
#   inflating: data/modified data/Validation/Real/real_10532.jpg
#   inflating: data/modified data/Validation/Real/real_10541.jpg
#   inflating: data/modified data/Validation/Real/real_10543.jpg
#   inflating: data/modified data/Validation/Real/real_10545.jpg
#   inflating: data/modified data/Validation/Real/real_10546.jpg
#   inflating: data/modified data/Validation/Real/real_10548.jpg
#   inflating: data/modified data/Validation/Real/real_10551.jpg
#   inflating: data/modified data/Validation/Real/real_10554.jpg
#   inflating: data/modified data/Validation/Real/real_10558.jpg
#   inflating: data/modified data/Validation/Real/real_10561.jpg
#   inflating: data/modified data/Validation/Real/real_10562.jpg
#   inflating: data/modified data/Validation/Real/real_10563.jpg
#   inflating: data/modified data/Validation/Real/real_10564.jpg
#   inflating: data/modified data/Validation/Real/real_10565.jpg
#   inflating: data/modified data/Validation/Real/real_10569.jpg
#   inflating: data/modified data/Validation/Real/real_10574.jpg
#   inflating: data/modified data/Validation/Real/real_10576.jpg
#   inflating: data/modified data/Validation/Real/real_10578.jpg
#   inflating: data/modified data/Validation/Real/real_10584.jpg
#   inflating: data/modified data/Validation/Real/real_10585.jpg
#   inflating: data/modified data/Validation/Real/real_10586.jpg
#   inflating: data/modified data/Validation/Real/real_10590.jpg
#   inflating: data/modified data/Validation/Real/real_10591.jpg
#   inflating: data/modified data/Validation/Real/real_10592.jpg
#   inflating: data/modified data/Validation/Real/real_10597.jpg
#   inflating: data/modified data/Validation/Real/real_10604.jpg
#   inflating: data/modified data/Validation/Real/real_10605.jpg
#   inflating: data/modified data/Validation/Real/real_10606.jpg
#   inflating: data/modified data/Validation/Real/real_10610.jpg
#   inflating: data/modified data/Validation/Real/real_10611.jpg
#   inflating: data/modified data/Validation/Real/real_10612.jpg
#   inflating: data/modified data/Validation/Real/real_10617.jpg
#   inflating: data/modified data/Validation/Real/real_10621.jpg
#   inflating: data/modified data/Validation/Real/real_10623.jpg
#   inflating: data/modified data/Validation/Real/real_10629.jpg
#   inflating: data/modified data/Validation/Real/real_10630.jpg
#   inflating: data/modified data/Validation/Real/real_10635.jpg
#   inflating: data/modified data/Validation/Real/real_10638.jpg
#   inflating: data/modified data/Validation/Real/real_1064.jpg
#   inflating: data/modified data/Validation/Real/real_10640.jpg
#   inflating: data/modified data/Validation/Real/real_10641.jpg
#   inflating: data/modified data/Validation/Real/real_10642.jpg
#   inflating: data/modified data/Validation/Real/real_10645.jpg
#   inflating: data/modified data/Validation/Real/real_10647.jpg
#   inflating: data/modified data/Validation/Real/real_10650.jpg
#   inflating: data/modified data/Validation/Real/real_10653.jpg
#   inflating: data/modified data/Validation/Real/real_10654.jpg
#   inflating: data/modified data/Validation/Real/real_1066.jpg
#   inflating: data/modified data/Validation/Real/real_10660.jpg
#   inflating: data/modified data/Validation/Real/real_10664.jpg
#   inflating: data/modified data/Validation/Real/real_10668.jpg
#   inflating: data/modified data/Validation/Real/real_10671.jpg
#   inflating: data/modified data/Validation/Real/real_10672.jpg
#   inflating: data/modified data/Validation/Real/real_10673.jpg
#   inflating: data/modified data/Validation/Real/real_10674.jpg
#   inflating: data/modified data/Validation/Real/real_10679.jpg
#   inflating: data/modified data/Validation/Real/real_10684.jpg
#   inflating: data/modified data/Validation/Real/real_10697.jpg
#   inflating: data/modified data/Validation/Real/real_10702.jpg
#   inflating: data/modified data/Validation/Real/real_10704.jpg
#   inflating: data/modified data/Validation/Real/real_10707.jpg
#   inflating: data/modified data/Validation/Real/real_10708.jpg
#   inflating: data/modified data/Validation/Real/real_10710.jpg
#   inflating: data/modified data/Validation/Real/real_10715.jpg
#   inflating: data/modified data/Validation/Real/real_10724.jpg
#   inflating: data/modified data/Validation/Real/real_10725.jpg
#   inflating: data/modified data/Validation/Real/real_10727.jpg
#   inflating: data/modified data/Validation/Real/real_10740.jpg
#   inflating: data/modified data/Validation/Real/real_10741.jpg
#   inflating: data/modified data/Validation/Real/real_10747.jpg
#   inflating: data/modified data/Validation/Real/real_10754.jpg
#   inflating: data/modified data/Validation/Real/real_10764.jpg
#   inflating: data/modified data/Validation/Real/real_10775.jpg
#   inflating: data/modified data/Validation/Real/real_10776.jpg
#   inflating: data/modified data/Validation/Real/real_10783.jpg
#   inflating: data/modified data/Validation/Real/real_10785.jpg
#   inflating: data/modified data/Validation/Real/real_10787.jpg
#   inflating: data/modified data/Validation/Real/real_10788.jpg
#   inflating: data/modified data/Validation/Real/real_10789.jpg
#   inflating: data/modified data/Validation/Real/real_10795.jpg
#   inflating: data/modified data/Validation/Real/real_10796.jpg
#   inflating: data/modified data/Validation/Real/real_108.jpg
#   inflating: data/modified data/Validation/Real/real_1080.jpg
#   inflating: data/modified data/Validation/Real/real_10800.jpg
#   inflating: data/modified data/Validation/Real/real_10801.jpg
#   inflating: data/modified data/Validation/Real/real_10806.jpg
#   inflating: data/modified data/Validation/Real/real_10808.jpg
#   inflating: data/modified data/Validation/Real/real_10810.jpg
#   inflating: data/modified data/Validation/Real/real_10813.jpg
#   inflating: data/modified data/Validation/Real/real_10815.jpg
#   inflating: data/modified data/Validation/Real/real_10823.jpg
#   inflating: data/modified data/Validation/Real/real_10829.jpg
#   inflating: data/modified data/Validation/Real/real_10850.jpg
#   inflating: data/modified data/Validation/Real/real_10856.jpg
#   inflating: data/modified data/Validation/Real/real_1086.jpg
#   inflating: data/modified data/Validation/Real/real_10861.jpg
#   inflating: data/modified data/Validation/Real/real_10863.jpg
#   inflating: data/modified data/Validation/Real/real_10864.jpg
#   inflating: data/modified data/Validation/Real/real_10872.jpg
#   inflating: data/modified data/Validation/Real/real_10873.jpg
#   inflating: data/modified data/Validation/Real/real_10874.jpg
#   inflating: data/modified data/Validation/Real/real_10876.jpg
#   inflating: data/modified data/Validation/Real/real_10877.jpg
#   inflating: data/modified data/Validation/Real/real_10878.jpg
#   inflating: data/modified data/Validation/Real/real_1088.jpg
#   inflating: data/modified data/Validation/Real/real_10881.jpg
#   inflating: data/modified data/Validation/Real/real_10886.jpg
#   inflating: data/modified data/Validation/Real/real_10887.jpg
#   inflating: data/modified data/Validation/Real/real_10890.jpg
#   inflating: data/modified data/Validation/Real/real_10891.jpg
#   inflating: data/modified data/Validation/Real/real_10894.jpg
#   inflating: data/modified data/Validation/Real/real_10901.jpg
#   inflating: data/modified data/Validation/Real/real_10904.jpg
#   inflating: data/modified data/Validation/Real/real_10906.jpg
#   inflating: data/modified data/Validation/Real/real_10907.jpg
#   inflating: data/modified data/Validation/Real/real_10908.jpg
#   inflating: data/modified data/Validation/Real/real_10923.jpg
#   inflating: data/modified data/Validation/Real/real_10931.jpg
#   inflating: data/modified data/Validation/Real/real_10933.jpg
#   inflating: data/modified data/Validation/Real/real_10935.jpg
#   inflating: data/modified data/Validation/Real/real_10951.jpg
#   inflating: data/modified data/Validation/Real/real_10952.jpg
#   inflating: data/modified data/Validation/Real/real_10958.jpg
#   inflating: data/modified data/Validation/Real/real_1096.jpg
#   inflating: data/modified data/Validation/Real/real_10964.jpg
#   inflating: data/modified data/Validation/Real/real_10971.jpg
#   inflating: data/modified data/Validation/Real/real_10974.jpg
#   inflating: data/modified data/Validation/Real/real_10975.jpg
#   inflating: data/modified data/Validation/Real/real_10985.jpg
#   inflating: data/modified data/Validation/Real/real_10987.jpg
#   inflating: data/modified data/Validation/Real/real_10992.jpg
#   inflating: data/modified data/Validation/Real/real_11004.jpg
#   inflating: data/modified data/Validation/Real/real_11010.jpg
#   inflating: data/modified data/Validation/Real/real_11012.jpg
#   inflating: data/modified data/Validation/Real/real_11015.jpg
#   inflating: data/modified data/Validation/Real/real_11016.jpg
#   inflating: data/modified data/Validation/Real/real_11019.jpg
#   inflating: data/modified data/Validation/Real/real_11020.jpg
#   inflating: data/modified data/Validation/Real/real_1103.jpg
#   inflating: data/modified data/Validation/Real/real_11031.jpg
#   inflating: data/modified data/Validation/Real/real_11032.jpg
#   inflating: data/modified data/Validation/Real/real_11042.jpg
#   inflating: data/modified data/Validation/Real/real_11052.jpg
#   inflating: data/modified data/Validation/Real/real_11058.jpg
#   inflating: data/modified data/Validation/Real/real_11062.jpg
#   inflating: data/modified data/Validation/Real/real_11067.jpg
#   inflating: data/modified data/Validation/Real/real_11068.jpg
#   inflating: data/modified data/Validation/Real/real_1107.jpg
#   inflating: data/modified data/Validation/Real/real_11070.jpg
#   inflating: data/modified data/Validation/Real/real_11080.jpg
#   inflating: data/modified data/Validation/Real/real_11081.jpg
#   inflating: data/modified data/Validation/Real/real_11082.jpg
#   inflating: data/modified data/Validation/Real/real_11089.jpg
#   inflating: data/modified data/Validation/Real/real_1109.jpg
#   inflating: data/modified data/Validation/Real/real_11108.jpg
#   inflating: data/modified data/Validation/Real/real_11113.jpg
#   inflating: data/modified data/Validation/Real/real_11128.jpg
#   inflating: data/modified data/Validation/Real/real_11130.jpg
#   inflating: data/modified data/Validation/Real/real_11132.jpg
#   inflating: data/modified data/Validation/Real/real_11134.jpg
#   inflating: data/modified data/Validation/Real/real_11135.jpg
#   inflating: data/modified data/Validation/Real/real_11136.jpg
#   inflating: data/modified data/Validation/Real/real_11137.jpg
#   inflating: data/modified data/Validation/Real/real_11147.jpg
#   inflating: data/modified data/Validation/Real/real_11148.jpg
#   inflating: data/modified data/Validation/Real/real_1115.jpg
# ...
#   inflating: data/modified data/Validation/Real/real_9004.jpg
#   inflating: data/modified data/Validation/Real/real_9011.jpg
#   inflating: data/modified data/Validation/Real/real_9012.jpg
#   inflating: data/modified data/Validation/Real/real_9022.jpg
#   inflating: data/modified data/Validation/Real/real_9031.jpg
#   inflating: data/modified data/Validation/Real/real_9033.jpg
#   inflating: data/modified data/Validation/Real/real_9037.jpg
#   inflating: data/modified data/Validation/Real/real_9047.jpg
#   inflating: data/modified data/Validation/Real/real_9057.jpg
#   inflating: data/modified data/Validation/Real/real_9058.jpg
#   inflating: data/modified data/Validation/Real/real_9060.jpg
#   inflating: data/modified data/Validation/Real/real_9075.jpg
#   inflating: data/modified data/Validation/Real/real_9076.jpg
#   inflating: data/modified data/Validation/Real/real_9079.jpg
#   inflating: data/modified data/Validation/Real/real_9081.jpg
#   inflating: data/modified data/Validation/Real/real_9086.jpg
#   inflating: data/modified data/Validation/Real/real_9099.jpg
#   inflating: data/modified data/Validation/Real/real_9107.jpg
#   inflating: data/modified data/Validation/Real/real_9110.jpg
#   inflating: data/modified data/Validation/Real/real_9112.jpg
#   inflating: data/modified data/Validation/Real/real_9122.jpg
#   inflating: data/modified data/Validation/Real/real_9123.jpg
#   inflating: data/modified data/Validation/Real/real_9125.jpg
#   inflating: data/modified data/Validation/Real/real_9126.jpg
#   inflating: data/modified data/Validation/Real/real_9130.jpg
#   inflating: data/modified data/Validation/Real/real_9132.jpg
#   inflating: data/modified data/Validation/Real/real_9139.jpg
#   inflating: data/modified data/Validation/Real/real_9145.jpg
#   inflating: data/modified data/Validation/Real/real_9152.jpg
#   inflating: data/modified data/Validation/Real/real_9153.jpg
#   inflating: data/modified data/Validation/Real/real_9154.jpg
#   inflating: data/modified data/Validation/Real/real_9159.jpg
#   inflating: data/modified data/Validation/Real/real_9162.jpg
#   inflating: data/modified data/Validation/Real/real_9163.jpg
#   inflating: data/modified data/Validation/Real/real_9165.jpg
#   inflating: data/modified data/Validation/Real/real_9178.jpg
#   inflating: data/modified data/Validation/Real/real_9179.jpg
#   inflating: data/modified data/Validation/Real/real_918.jpg
#   inflating: data/modified data/Validation/Real/real_9182.jpg
#   inflating: data/modified data/Validation/Real/real_9183.jpg
#   inflating: data/modified data/Validation/Real/real_9185.jpg
#   inflating: data/modified data/Validation/Real/real_9191.jpg
#   inflating: data/modified data/Validation/Real/real_9196.jpg
#   inflating: data/modified data/Validation/Real/real_9197.jpg
#   inflating: data/modified data/Validation/Real/real_9199.jpg
#   inflating: data/modified data/Validation/Real/real_920.jpg
#   inflating: data/modified data/Validation/Real/real_9200.jpg
#   inflating: data/modified data/Validation/Real/real_9203.jpg
#   inflating: data/modified data/Validation/Real/real_9207.jpg
#   inflating: data/modified data/Validation/Real/real_9210.jpg
#   inflating: data/modified data/Validation/Real/real_9221.jpg
#   inflating: data/modified data/Validation/Real/real_9223.jpg
#   inflating: data/modified data/Validation/Real/real_9224.jpg
#   inflating: data/modified data/Validation/Real/real_9230.jpg
#   inflating: data/modified data/Validation/Real/real_9233.jpg
#   inflating: data/modified data/Validation/Real/real_9235.jpg
#   inflating: data/modified data/Validation/Real/real_9237.jpg
#   inflating: data/modified data/Validation/Real/real_924.jpg
#   inflating: data/modified data/Validation/Real/real_9240.jpg
#   inflating: data/modified data/Validation/Real/real_9242.jpg
#   inflating: data/modified data/Validation/Real/real_9254.jpg
#   inflating: data/modified data/Validation/Real/real_9255.jpg
#   inflating: data/modified data/Validation/Real/real_9261.jpg
#   inflating: data/modified data/Validation/Real/real_9262.jpg
#   inflating: data/modified data/Validation/Real/real_9269.jpg
#   inflating: data/modified data/Validation/Real/real_9274.jpg
#   inflating: data/modified data/Validation/Real/real_9277.jpg
#   inflating: data/modified data/Validation/Real/real_9285.jpg
#   inflating: data/modified data/Validation/Real/real_9286.jpg
#   inflating: data/modified data/Validation/Real/real_9288.jpg
#   inflating: data/modified data/Validation/Real/real_9296.jpg
#   inflating: data/modified data/Validation/Real/real_9297.jpg
#   inflating: data/modified data/Validation/Real/real_9306.jpg
#   inflating: data/modified data/Validation/Real/real_9308.jpg
#   inflating: data/modified data/Validation/Real/real_9309.jpg
#   inflating: data/modified data/Validation/Real/real_931.jpg
#   inflating: data/modified data/Validation/Real/real_9312.jpg
#   inflating: data/modified data/Validation/Real/real_9314.jpg
#   inflating: data/modified data/Validation/Real/real_9316.jpg
#   inflating: data/modified data/Validation/Real/real_9317.jpg
#   inflating: data/modified data/Validation/Real/real_932.jpg
#   inflating: data/modified data/Validation/Real/real_9325.jpg
#   inflating: data/modified data/Validation/Real/real_9326.jpg
#   inflating: data/modified data/Validation/Real/real_9327.jpg
#   inflating: data/modified data/Validation/Real/real_9336.jpg
#   inflating: data/modified data/Validation/Real/real_934.jpg
#   inflating: data/modified data/Validation/Real/real_935.jpg
#   inflating: data/modified data/Validation/Real/real_9350.jpg
#   inflating: data/modified data/Validation/Real/real_9356.jpg
#   inflating: data/modified data/Validation/Real/real_9358.jpg
#   inflating: data/modified data/Validation/Real/real_9360.jpg
#   inflating: data/modified data/Validation/Real/real_9365.jpg
#   inflating: data/modified data/Validation/Real/real_9366.jpg
#   inflating: data/modified data/Validation/Real/real_9372.jpg
#   inflating: data/modified data/Validation/Real/real_9373.jpg
#   inflating: data/modified data/Validation/Real/real_9386.jpg
#   inflating: data/modified data/Validation/Real/real_94.jpg
#   inflating: data/modified data/Validation/Real/real_9405.jpg
#   inflating: data/modified data/Validation/Real/real_9410.jpg
#   inflating: data/modified data/Validation/Real/real_9418.jpg
#   inflating: data/modified data/Validation/Real/real_9440.jpg
#   inflating: data/modified data/Validation/Real/real_9449.jpg
#   inflating: data/modified data/Validation/Real/real_945.jpg
#   inflating: data/modified data/Validation/Real/real_9453.jpg
#   inflating: data/modified data/Validation/Real/real_9455.jpg
#   inflating: data/modified data/Validation/Real/real_9459.jpg
#   inflating: data/modified data/Validation/Real/real_946.jpg
#   inflating: data/modified data/Validation/Real/real_9461.jpg
#   inflating: data/modified data/Validation/Real/real_9462.jpg
#   inflating: data/modified data/Validation/Real/real_9468.jpg
#   inflating: data/modified data/Validation/Real/real_9469.jpg
#   inflating: data/modified data/Validation/Real/real_947.jpg
#   inflating: data/modified data/Validation/Real/real_9473.jpg
#   inflating: data/modified data/Validation/Real/real_9475.jpg
#   inflating: data/modified data/Validation/Real/real_9478.jpg
#   inflating: data/modified data/Validation/Real/real_9479.jpg
#   inflating: data/modified data/Validation/Real/real_9483.jpg
#   inflating: data/modified data/Validation/Real/real_949.jpg
#   inflating: data/modified data/Validation/Real/real_9492.jpg
#   inflating: data/modified data/Validation/Real/real_9497.jpg
#   inflating: data/modified data/Validation/Real/real_9502.jpg
#   inflating: data/modified data/Validation/Real/real_9503.jpg
#   inflating: data/modified data/Validation/Real/real_9505.jpg
#   inflating: data/modified data/Validation/Real/real_9508.jpg
#   inflating: data/modified data/Validation/Real/real_9523.jpg
#   inflating: data/modified data/Validation/Real/real_9527.jpg
#   inflating: data/modified data/Validation/Real/real_9528.jpg
#   inflating: data/modified data/Validation/Real/real_9533.jpg
#   inflating: data/modified data/Validation/Real/real_954.jpg
#   inflating: data/modified data/Validation/Real/real_9545.jpg
#   inflating: data/modified data/Validation/Real/real_9548.jpg
#   inflating: data/modified data/Validation/Real/real_9549.jpg
#   inflating: data/modified data/Validation/Real/real_9550.jpg
#   inflating: data/modified data/Validation/Real/real_9553.jpg
#   inflating: data/modified data/Validation/Real/real_9555.jpg
#   inflating: data/modified data/Validation/Real/real_9560.jpg
#   inflating: data/modified data/Validation/Real/real_9568.jpg
#   inflating: data/modified data/Validation/Real/real_9572.jpg
#   inflating: data/modified data/Validation/Real/real_9574.jpg
#   inflating: data/modified data/Validation/Real/real_9581.jpg
#   inflating: data/modified data/Validation/Real/real_9582.jpg
#   inflating: data/modified data/Validation/Real/real_9589.jpg
#   inflating: data/modified data/Validation/Real/real_9608.jpg
#   inflating: data/modified data/Validation/Real/real_9609.jpg
#   inflating: data/modified data/Validation/Real/real_9614.jpg
#   inflating: data/modified data/Validation/Real/real_9616.jpg
#   inflating: data/modified data/Validation/Real/real_9618.jpg
#   inflating: data/modified data/Validation/Real/real_9622.jpg
#   inflating: data/modified data/Validation/Real/real_9623.jpg
#   inflating: data/modified data/Validation/Real/real_9628.jpg
#   inflating: data/modified data/Validation/Real/real_9629.jpg
#   inflating: data/modified data/Validation/Real/real_963.jpg
#   inflating: data/modified data/Validation/Real/real_9630.jpg
#   inflating: data/modified data/Validation/Real/real_9632.jpg
#   inflating: data/modified data/Validation/Real/real_9636.jpg
#   inflating: data/modified data/Validation/Real/real_9641.jpg
#   inflating: data/modified data/Validation/Real/real_9642.jpg
#   inflating: data/modified data/Validation/Real/real_9644.jpg
#   inflating: data/modified data/Validation/Real/real_9653.jpg
#   inflating: data/modified data/Validation/Real/real_9654.jpg
#   inflating: data/modified data/Validation/Real/real_9655.jpg
#   inflating: data/modified data/Validation/Real/real_9661.jpg
#   inflating: data/modified data/Validation/Real/real_9663.jpg
#   inflating: data/modified data/Validation/Real/real_9674.jpg
#   inflating: data/modified data/Validation/Real/real_9677.jpg
#   inflating: data/modified data/Validation/Real/real_9681.jpg
#   inflating: data/modified data/Validation/Real/real_9684.jpg
#   inflating: data/modified data/Validation/Real/real_9686.jpg
#   inflating: data/modified data/Validation/Real/real_969.jpg
#   inflating: data/modified data/Validation/Real/real_9693.jpg
#   inflating: data/modified data/Validation/Real/real_9695.jpg
#   inflating: data/modified data/Validation/Real/real_9696.jpg
#   inflating: data/modified data/Validation/Real/real_9700.jpg
#   inflating: data/modified data/Validation/Real/real_9701.jpg
#   inflating: data/modified data/Validation/Real/real_9702.jpg
#   inflating: data/modified data/Validation/Real/real_9704.jpg
#   inflating: data/modified data/Validation/Real/real_9705.jpg
#   inflating: data/modified data/Validation/Real/real_9708.jpg
#   inflating: data/modified data/Validation/Real/real_9710.jpg
#   inflating: data/modified data/Validation/Real/real_9716.jpg
#   inflating: data/modified data/Validation/Real/real_9720.jpg
#   inflating: data/modified data/Validation/Real/real_9722.jpg
#   inflating: data/modified data/Validation/Real/real_9723.jpg
#   inflating: data/modified data/Validation/Real/real_9725.jpg
#   inflating: data/modified data/Validation/Real/real_9729.jpg
#   inflating: data/modified data/Validation/Real/real_9732.jpg
#   inflating: data/modified data/Validation/Real/real_9738.jpg
#   inflating: data/modified data/Validation/Real/real_9741.jpg
#   inflating: data/modified data/Validation/Real/real_9746.jpg
#   inflating: data/modified data/Validation/Real/real_976.jpg
#   inflating: data/modified data/Validation/Real/real_9764.jpg
#   inflating: data/modified data/Validation/Real/real_9768.jpg
#   inflating: data/modified data/Validation/Real/real_977.jpg
#   inflating: data/modified data/Validation/Real/real_9776.jpg
#   inflating: data/modified data/Validation/Real/real_978.jpg
#   inflating: data/modified data/Validation/Real/real_9780.jpg
#   inflating: data/modified data/Validation/Real/real_9784.jpg
#   inflating: data/modified data/Validation/Real/real_9787.jpg
#   inflating: data/modified data/Validation/Real/real_9800.jpg
#   inflating: data/modified data/Validation/Real/real_9806.jpg
#   inflating: data/modified data/Validation/Real/real_9807.jpg
#   inflating: data/modified data/Validation/Real/real_9811.jpg
#   inflating: data/modified data/Validation/Real/real_9816.jpg
#   inflating: data/modified data/Validation/Real/real_9818.jpg
#   inflating: data/modified data/Validation/Real/real_9823.jpg
#   inflating: data/modified data/Validation/Real/real_9828.jpg
#   inflating: data/modified data/Validation/Real/real_9829.jpg
#   inflating: data/modified data/Validation/Real/real_983.jpg
#   inflating: data/modified data/Validation/Real/real_9834.jpg
#   inflating: data/modified data/Validation/Real/real_9837.jpg
#   inflating: data/modified data/Validation/Real/real_9846.jpg
#   inflating: data/modified data/Validation/Real/real_9851.jpg
#   inflating: data/modified data/Validation/Real/real_9855.jpg
#   inflating: data/modified data/Validation/Real/real_9859.jpg
#   inflating: data/modified data/Validation/Real/real_9860.jpg
#   inflating: data/modified data/Validation/Real/real_9861.jpg
#   inflating: data/modified data/Validation/Real/real_9865.jpg
#   inflating: data/modified data/Validation/Real/real_987.jpg
#   inflating: data/modified data/Validation/Real/real_9870.jpg
#   inflating: data/modified data/Validation/Real/real_9873.jpg
#   inflating: data/modified data/Validation/Real/real_9878.jpg
#   inflating: data/modified data/Validation/Real/real_9883.jpg
#   inflating: data/modified data/Validation/Real/real_9888.jpg
#   inflating: data/modified data/Validation/Real/real_9892.jpg
#   inflating: data/modified data/Validation/Real/real_9894.jpg
#   inflating: data/modified data/Validation/Real/real_9895.jpg
#   inflating: data/modified data/Validation/Real/real_990.jpg
#   inflating: data/modified data/Validation/Real/real_9904.jpg
#   inflating: data/modified data/Validation/Real/real_9905.jpg
#   inflating: data/modified data/Validation/Real/real_9912.jpg
#   inflating: data/modified data/Validation/Real/real_9918.jpg
#   inflating: data/modified data/Validation/Real/real_9922.jpg
#   inflating: data/modified data/Validation/Real/real_9925.jpg
#   inflating: data/modified data/Validation/Real/real_9927.jpg
#   inflating: data/modified data/Validation/Real/real_9928.jpg
#   inflating: data/modified data/Validation/Real/real_9936.jpg
#   inflating: data/modified data/Validation/Real/real_9939.jpg
#   inflating: data/modified data/Validation/Real/real_9944.jpg
#   inflating: data/modified data/Validation/Real/real_9952.jpg
#   inflating: data/modified data/Validation/Real/real_9954.jpg
#   inflating: data/modified data/Validation/Real/real_9962.jpg
#   inflating: data/modified data/Validation/Real/real_9963.jpg
#   inflating: data/modified data/Validation/Real/real_9977.jpg
#   inflating: data/modified data/Validation/Real/real_9979.jpg
#   inflating: data/modified data/Validation/Real/real_9983.jpg
#   inflating: data/modified data/Validation/Real/real_9986.jpg
#   inflating: data/modified data/Validation/Real/real_9990.jpg
#   inflating: data/modified data/Validation/Real/real_9991.jpg
#   inflating: data/modified data/Validation/Real/real_9992.jpg
#   inflating: data/modified data/Validation/Real/real_9998.jpg

# %%
import torch
import torchvision
from torchvision import datasets
from torchvision import transforms as T # for simplifying the transforms
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, sampler, random_split
from torchvision import models
import numpy as np

# %%
# !pip install timm
# Out:
# Collecting timm
#   Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.17.1+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.20.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 52.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 82.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->timm)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->timm)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, timm
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 timm-0.9.16

# %%
import timm
from timm.loss import LabelSmoothingCrossEntropy

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
from tqdm import tqdm
import time
import copy

# %%
def get_classes(data_dir):
    all_data = datasets.ImageFolder(data_dir)
    return all_data.classes

# %%
import os
def get_data_loaders(data_dir, batch_size, train = False):
    if train:
        #train
        transform = T.Compose([
            T.RandomHorizontalFlip(),
            T.RandomVerticalFlip(),
            T.RandomApply(torch.nn.ModuleList([T.ColorJitter()]), p=0.25),
            T.Resize(256),
            T.CenterCrop(224),
            T.ToTensor(),
            T.Normalize(timm.data.IMAGENET_DEFAULT_MEAN, timm.data.IMAGENET_DEFAULT_STD), # imagenet means
            T.RandomErasing(p=0.1, value='random')
        ])
        train_data = datasets.ImageFolder(os.path.join(data_dir, "Train/"), transform = transform)
        train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=4)
        return train_loader, len(train_data)
    else:
        # val/test
        transform = T.Compose([ # We dont need augmentation for test transforms
            T.Resize(256),
            T.CenterCrop(224),
            T.ToTensor(),
            T.Normalize(timm.data.IMAGENET_DEFAULT_MEAN, timm.data.IMAGENET_DEFAULT_STD), # imagenet means
        ])
        val_data = datasets.ImageFolder(os.path.join(data_dir, "Validation/"), transform=transform)
        test_data = datasets.ImageFolder(os.path.join(data_dir, "Test/"), transform=transform)
        val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True, num_workers=4)
        test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=4)
        return val_loader, test_loader, len(val_data), len(test_data)

# %%
classes = get_classes("/content/data/modified data/Test")
print(classes, len(classes))
# Out:
# ['Fake', 'Real'] 2

# %%
dataset_path = "/content/data/modified data"

# %%
# !ls "/content/data/modified data"
# Out:
# Test  Train  Validation

# %%
(train_loader, train_data_len) = get_data_loaders(dataset_path, 128, train=True)
(val_loader, test_loader, valid_data_len, test_data_len) = get_data_loaders(dataset_path, 32, train=False)

# %%
dataloaders = {
    "train": train_loader,
    "val": val_loader
}
dataset_sizes = {
    "train": train_data_len,
    "val": valid_data_len
}

# %%
print(len(train_loader), len(val_loader), len(test_loader))
# Out:
# 252 284 79

# %%
print(train_data_len, valid_data_len, test_data_len)
# Out:
# 32200 9068 2507

# %%
# now, for the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
HUB_URL = "SharanSMenon/swin-transformer-hub:main"
MODEL_NAME = "swin_tiny_patch4_window7_224"
# check hubconf for more models.
model = torch.hub.load(HUB_URL, MODEL_NAME, pretrained=True) # load from torch hub
# Out:
# Downloading: "https://github.com/SharanSMenon/swin-transformer-hub/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth" to /root/.cache/torch/hub/checkpoints/swin_tiny_patch4_window7_224.pth
# 100%|██████████| 109M/109M [00:00<00:00, 280MB/s]

# %%
import torch
import torch.nn as nn

# Define the device (GPU or CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Freeze the parameters of the pretrained model
for param in model.parameters():
    param.requires_grad = False

# Get the number of input features for the new head
n_inputs = model.head.in_features

# Define the new head of the model
model.head = nn.Sequential(
    nn.Linear(n_inputs, 512),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(512, len(classes))
)

# Move the new head to the specified device
model.head = model.head.to(device)

print(model.head)
# Out:
# Sequential(
#   (0): Linear(in_features=768, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.3, inplace=False)
#   (3): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
criterion = LabelSmoothingCrossEntropy()
criterion = criterion.to(device)
optimizer = optim.AdamW(model.head.parameters(), lr=0.001)

# %%
# lr scheduler
exp_lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.97)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Assuming dataloaders, dataset_sizes, device, criterion, optimizer, and exp_lr_scheduler are defined earlier

def save_checkpoint(model, optimizer, epoch, best_model=False, directory='/content/gdrive/My Drive/'):
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }
    if best_model:
        torch.save(checkpoint, directory + 'best_model.pt')
    else:
        torch.save(checkpoint, directory + 'checkpoint_epoch{}.pt'.format(epoch))

def load_checkpoint(model, optimizer, checkpoint_path):
    checkpoint = torch.load(checkpoint_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epoch = checkpoint['epoch']
    return model, optimizer, epoch

def load_recent_checkpoint(model, optimizer, directory='/content/gdrive/My Drive/'):
    checkpoint_files = os.listdir(directory)
    checkpoint_files = [f for f in checkpoint_files if 'checkpoint_epoch' in f]
    if checkpoint_files:
        latest_checkpoint = max(checkpoint_files, key=lambda x: int(x.split('epoch')[1].split('.pt')[0]))
        latest_epoch = int(latest_checkpoint.split('epoch')[1].split('.pt')[0])
        model, optimizer, epoch = load_checkpoint(model, optimizer, directory + latest_checkpoint)
        return model, optimizer, epoch
    else:
        return model, optimizer, 0

def train_model(model, criterion, optimizer, scheduler, dataloaders, dataset_sizes, device, num_epochs=5, resume_training=False):
    since = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    start_epoch = 0

    if resume_training:
        model, optimizer, start_epoch = load_recent_checkpoint(model, optimizer)

    model = model.to(device)  # Move model to device here

    for epoch in range(start_epoch, num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print("-"*10)

        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0.0

            for inputs, labels in tqdm(dataloaders[phase]):
                inputs = inputs.to(device)  # Move input data to device
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc =  running_corrects.double() / dataset_sizes[phase]

            print("{} Loss: {:.4f} Acc: {:.4f}".format(phase, epoch_loss, epoch_acc))

            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

        save_checkpoint(model, optimizer, epoch)

        if (epoch + 1) % 10 == 0:
            save_checkpoint(model, optimizer, epoch, best_model=True)

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print("Best Val Acc: {:.4f}".format(best_acc))

    model.load_state_dict(best_model_wts)
    return model


# Call the train_model function
model_ft = train_model(model, criterion, optimizer, exp_lr_scheduler, dataloaders, dataset_sizes, device, num_epochs=75, resume_training=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Epoch 69/74
# ----------
# 100%|██████████| 252/252 [02:38<00:00,  1.59it/s]
# train Loss: 0.2959 Acc: 0.9577
# 100%|██████████| 284/284 [00:44<00:00,  6.33it/s]
# val Loss: 0.4666 Acc: 0.8419
#
# Epoch 70/74
# ----------
# 100%|██████████| 252/252 [02:38<00:00,  1.59it/s]
# train Loss: 0.2949 Acc: 0.9600
# 100%|██████████| 284/284 [00:44<00:00,  6.35it/s]
# val Loss: 0.4632 Acc: 0.8415
#
# Epoch 71/74
# ----------
# 100%|██████████| 252/252 [02:38<00:00,  1.59it/s]
# train Loss: 0.2919 Acc: 0.9624
# 100%|██████████| 284/284 [00:45<00:00,  6.29it/s]
# val Loss: 0.4594 Acc: 0.8444
#
# Epoch 72/74
# ----------
# 100%|██████████| 252/252 [02:38<00:00,  1.59it/s]
# train Loss: 0.2913 Acc: 0.9608
# 100%|██████████| 284/284 [00:44<00:00,  6.38it/s]
# val Loss: 0.4637 Acc: 0.8412
#
# Epoch 73/74
# ----------
# 100%|██████████| 252/252 [02:37<00:00,  1.60it/s]
# train Loss: 0.2911 Acc: 0.9620
# 100%|██████████| 284/284 [00:44<00:00,  6.36it/s]
# val Loss: 0.4604 Acc: 0.8444
#
# Epoch 74/74
# ----------
# 100%|██████████| 252/252 [02:38<00:00,  1.59it/s]
# train Loss: 0.2928 Acc: 0.9585
# 100%|██████████| 284/284 [00:45<00:00,  6.28it/s]
# val Loss: 0.4614 Acc: 0.8454
#
# Training complete in 20m 32s
# Best Val Acc: 0.8454
